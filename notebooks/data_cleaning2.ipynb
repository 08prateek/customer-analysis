# %%
import pandas as pd

# %%
df = pd.read_csv("f:/Prateek/Study material/Datamites/customer-segmentation/data/raw/rawfile2.csv")

# %%
df.head(5)
# Out:
#   invoice_date invoice_no customer_id  gender  age      shopping_mall  \
# 0   15-08-2021    I212260     C327200  Female   43     Viaport Outlet
# 1   19-10-2022    I212268     C296817  Female   26   Mall of Istanbul
# 2   19-09-2021    I212269     C305605  Female   56             Kanyon
# 3   09-01-2023    I212270     C198502  Female   38  Emaar Square Mall
# 4   10-03-2022    I212272     C552066    Male   56          Metrocity
#
#      category  quantity    price payment_method  Sales amount
# 0  Technology         4  4200.00           Cash      16800.00
# 1       Shoes         2  1200.34           Cash       2400.68
# 2    Souvenir         4    46.92    Credit Card        187.68
# 3    Clothing         5  1500.40    Credit Card       7502.00
# 4    Clothing         1   300.08           Cash        300.08

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35000 entries, 0 to 34999
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   invoice_date    35000 non-null  object
#  1   invoice_no      35000 non-null  object
#  2   customer_id     35000 non-null  object
#  3   gender          35000 non-null  object
#  4   age             35000 non-null  int64
#  5   shopping_mall   35000 non-null  object
#  6   category        35000 non-null  object
#  7   quantity        35000 non-null  int64
#  8   price           35000 non-null  float64
#  9   payment_method  35000 non-null  object
#  10  Sales amount    35000 non-null  float64
# dtypes: float64(2), int64(2), object(7)
# memory usage: 2.9+ MB

# %%
df.describe()
# Out:
#                 age      quantity         price  Sales amount
# count  35000.000000  35000.000000  35000.000000  35000.000000
# mean      43.376257      2.997800    689.497351   2526.799880
# std       14.997591      1.411897    939.126963   4201.749324
# min       18.000000      1.000000      5.230000      5.230000
# 25%       30.000000      2.000000     40.660000    130.750000
# 50%       43.000000      3.000000    203.300000    600.170000
# 75%       56.000000      4.000000   1200.320000   2700.720000
# max       69.000000      5.000000   5250.000000  26250.000000

# %%
df.isnull().sum()
# Out:
# invoice_date      0
# invoice_no        0
# customer_id       0
# gender            0
# age               0
# shopping_mall     0
# category          0
# quantity          0
# price             0
# payment_method    0
# Sales amount      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.dtypes
# Out:
# invoice_date       object
# invoice_no         object
# customer_id        object
# gender             object
# age                 int64
# shopping_mall      object
# category           object
# quantity            int64
# price             float64
# payment_method     object
# Sales amount      float64
# dtype: object

# %%
df['invoice_date'] = df['invoice_date'].dt.strftime('%d-%m-%Y')

# %%
df['invoice_date'] = pd.to_datetime(df['invoice_date'], dayfirst=True)

# %%
df.dtypes
# Out:
# invoice_date      datetime64[ns]
# invoice_no                object
# customer_id               object
# gender                    object
# age                        int64
# shopping_mall             object
# category                  object
# quantity                   int64
# price                    float64
# payment_method            object
# Sales amount             float64
# dtype: object

# %%
df.head(5)
# Out:
#   invoice_date invoice_no customer_id  gender  age      shopping_mall  \
# 0   2021-08-15    I212260     C327200  Female   43     Viaport Outlet
# 1   2022-10-19    I212268     C296817  Female   26   Mall of Istanbul
# 2   2021-09-19    I212269     C305605  Female   56             Kanyon
# 3   2023-01-09    I212270     C198502  Female   38  Emaar Square Mall
# 4   2022-03-10    I212272     C552066    Male   56          Metrocity
#
#      category  quantity    price payment_method  Sales amount
# 0  Technology         4  4200.00           Cash      16800.00
# 1       Shoes         2  1200.34           Cash       2400.68
# 2    Souvenir         4    46.92    Credit Card        187.68
# 3    Clothing         5  1500.40    Credit Card       7502.00
# 4    Clothing         1   300.08           Cash        300.08

# %%
for col in df.select_dtypes(include=['object']).columns:
    df[col] = df[col].str.strip()

# %%
df[['age', 'price', 'quantity']].describe()
# Out:
#                 age         price      quantity
# count  35000.000000  35000.000000  35000.000000
# mean      43.376257    689.497351      2.997800
# std       14.997591    939.126963      1.411897
# min       18.000000      5.230000      1.000000
# 25%       30.000000     40.660000      2.000000
# 50%       43.000000    203.300000      3.000000
# 75%       56.000000   1200.320000      4.000000
# max       69.000000   5250.000000      5.000000

# %%
df.head(5)
# Out:
#   invoice_date invoice_no customer_id  gender  age      shopping_mall  \
# 0   2021-08-15    I212260     C327200  Female   43     Viaport Outlet
# 1   2022-10-19    I212268     C296817  Female   26   Mall of Istanbul
# 2   2021-09-19    I212269     C305605  Female   56             Kanyon
# 3   2023-01-09    I212270     C198502  Female   38  Emaar Square Mall
# 4   2022-03-10    I212272     C552066    Male   56          Metrocity
#
#      category  quantity    price payment_method  Sales amount
# 0  Technology         4  4200.00           Cash      16800.00
# 1       Shoes         2  1200.34           Cash       2400.68
# 2    Souvenir         4    46.92    Credit Card        187.68
# 3    Clothing         5  1500.40    Credit Card       7502.00
# 4    Clothing         1   300.08           Cash        300.08

# %%
# Specify the file path for the processed file
output_file_path = r"f:/Prateek/Study material/Datamites/customer-segmentation/data/processed/processedfile2.csv"

# Export the cleaned dataframe to CSV
df.to_csv(output_file_path, index=False)  # index=False to avoid saving row indices
